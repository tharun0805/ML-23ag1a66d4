# %% [markdown]
# <a href="https://colab.research.google.com/github/tharun0805/ML-23ag1a66d4/blob/main/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x= np.array([1,8])
y=np.array([3,10])
plt.plot(x,y)
plt.show()

# %%
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Line Chart")
plt.show()
